# %%
# %reload_ext autoreload
# %autoreload 2

# %%
ACHIEVEMENTS ="""
<achievements>
{section_data}
</achievements>

<job_description>
{job_description}
</job_description>
"""

# %%
ACHIEVEMENTS.format(section_data = "sec_d", job_description = "job_d")
# Out:
# '\n<achievements>\nsec_d\n</achievements>\n\n<job_description>\njob_d\n</job_description>\n'
